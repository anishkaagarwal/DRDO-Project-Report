# %%
import matplotlib.pyplot as plt
import numpy as np

# Given data
v0 = {
    "Cs": {
        "D1": 335.116048807 * 10**12,
        "D2": 351.72571850 * 10**12,
    },
    "Rb": {
        "D1": 377.1074635 * 10**12,
        "D2": 384.2304844685 * 10**12,
    }
}

vg = {
    "Cs": {
        "D1": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0],
        "D2": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0]
    },
    "Rb": {
        "D1": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0],
        "D2": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0]
    }
}

ve = {
    "Cs": {
        "D1": [0, 0, 0, -656.820 * 10**6, 510.860 * 10**6, 0, 0],
        "D2": [0, 0, -339.7128 * 10**6, -188.4885 * 10**6, 12.79851 * 10**6, 263.8906 * 10**6, 0]
    },
    "Rb": {
        "D1": [0, -510.410 * 10**6, 306.246 * 10**6, 0, 0, 0, 0],
        "D2": [-302.0738 * 10**6, -229.8518 * 10**6, -72.9113 * 10**6, 193.7408 * 10**6, 0, 0, 0]
    }
}

# Calculating Raman detuning model (simplified example)
def raman_detuning(v0, vg, ve):
    return v0 + np.array(vg) + np.array(ve)

# Raman detuning for Cs and Rb D1/D2 transitions
detuning_Cs_D1 = raman_detuning(v0["Cs"]["D1"], vg["Cs"]["D1"], ve["Cs"]["D1"])
detuning_Cs_D2 = raman_detuning(v0["Cs"]["D2"], vg["Cs"]["D2"], ve["Cs"]["D2"])
detuning_Rb_D1 = raman_detuning(v0["Rb"]["D1"], vg["Rb"]["D1"], ve["Rb"]["D1"])
detuning_Rb_D2 = raman_detuning(v0["Rb"]["D2"], vg["Rb"]["D2"], ve["Rb"]["D2"])

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(detuning_Cs_D1, label='Cs D1')
plt.plot(detuning_Cs_D2, label='Cs D2')
plt.plot(detuning_Rb_D1, label='Rb D1')
plt.plot(detuning_Rb_D2, label='Rb D2')

plt.xlabel('Index')
plt.ylabel('Frequency (Hz)')
plt.title('Raman Detuning Model for Cs and Rb D1/D2 Transitions')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
v0 = {
    "Cs": {
        "D1": 335.116048807 * 10**12,
        "D2": 351.72571850 * 10**12,
    },
    "Rb": {
        "D1": 377.1074635 * 10**12,
        "D2": 384.2304844685 * 10**12,
    }
}

vg = {
    "Cs": {
        "D1": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0],
        "D2": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0]
    },
    "Rb": {
        "D1": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0],
        "D2": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0]
    }
}

ve = {
    "Cs": {
        "D1": [0, 0, 0, -656.820 * 10**6, 510.860 * 10**6, 0, 0],
        "D2": [0, 0, -339.7128 * 10**6, -188.4885 * 10**6, 12.79851 * 10**6, 263.8906 * 10**6, 0]
    },
    "Rb": {
        "D1": [0, -510.410 * 10**6, 306.246 * 10**6, 0, 0, 0, 0],
        "D2": [-302.0738 * 10**6, -229.8518 * 10**6, -72.9113 * 10**6, 193.7408 * 10**6, 0, 0, 0]
    }
    

# Calculate absorption cross-section (simplified example)
def absorption_cross_section(v0, vg, ve):
    return v0 + np.array(vg) + np.array(ve)

# Absorption cross-section for Cs and Rb D1/D2 transitions
absorption_Cs_D1 = absorption_cross_section(v0["Cs"]["D1"], vg["Cs"]["D1"], ve["Cs"]["D1"])
absorption_Cs_D2 = absorption_cross_section(v0["Cs"]["D2"], vg["Cs"]["D2"], ve["Cs"]["D2"])
absorption_Rb_D1 = absorption_cross_section(v0["Rb"]["D1"], vg["Rb"]["D1"], ve["Rb"]["D1"])
absorption_Rb_D2 = absorption_cross_section(v0["Rb"]["D2"], vg["Rb"]["D2"], ve["Rb"]["D2"])

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(absorption_Cs_D1, label='Cs D1 Absorption')
plt.plot(absorption_Cs_D2, label='Cs D2 Absorption')
plt.plot(absorption_Rb_D1, label='Rb D1 Absorption')
plt.plot(absorption_Rb_D2, label='Rb D2 Absorption')

plt.xlabel('Index')
plt.ylabel('Frequency (Hz)')
plt.title('Absorption Cross-Section for Cs and Rb D1/D2 Transitions')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   File "C:\Users\anush\AppData\Local\Temp\ipykernel_8792\2766377900.py", line 39
#     def absorption_cross_section(v0, vg, ve):
#     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.special as sp
import scipy.constants as const
from sympy.physics.wigner import wigner_6j
from scipy.constants import physical_constants
import math
from sklearn.metrics import auc
from scipy.signal import chirp, find_peaks, peak_widths


class absorption_profile:
    def __init__(self, vap, Dx, bg, P_bg, T_vap, L_cell, samples, Range):
        self.v0=v0[vap][Dx]
        self.Range = Range*10**9
        vmin=self.v0-self.Range; vmax=self.v0+self.Range
        self.samples=samples
        self.v=np.linspace(vmin, vmax, num=samples)
        self.vf=self.vf(v0[vap][Dx],vg[vap][Dx],ve[vap][Dx])
        print(self.vf)
        self.lines=list(self.vf.keys())
        self.D0 = D0[vap][bg] #diffusion coefficient for Cs/Rb vapor in buffer gas x
        self.m = M_vap[vap]
        self.f = f[vap][Dx]
        self.I = I[vap]
        self.J=0.5; self.J_= 0.5 if(Dx =="D1") else 1.5

        self.yN=yN[vap][Dx]
        self.yB=yB[vap][Dx][bg]
        self.delS=delS[vap][Dx][bg]

        self.Lcell = L_cell *10**-3 #to mm
        self.P_bg_torr=P_bg
        self.P_bg = P_bg *133.32236842105263 #buffer gas pressure, to pascal
        self.T_vap = T_vap + 273.15 #vapour temperature, in K
        
    def vf(self,vge,vg,ve):
        v={}
        for i in range(len(vg)):
            for j in range (len(ve)):
                label=int(str(i)+str(j))
                value=vge+vg[i]+ve[j]
                if vg[i]!=0 and ve[j]!=0 and abs(j-i)<2:
                    v.update({label:value})
        return v
    
    def gammaL(self):
        yB = self.yB
        yN = self.yN
        P_in =self.P_bg_torr
        self.gamL = yB*P_in + yN
        return self.gamL

    def gammaG(self,x):    

        vf = self.vf[x]
        m = self.m
        T=self.T_vap
        #print(vf, kb, T, m, c, math.log(2))
        gamG = vf*(np.sqrt((8*kb*T*math.log(2))/(m*(c**2))))
        return gamG

    def vf_new(self):

        vf = self.vf
        delS = self.delS
        P_in = self.P_bg
        vf_new = delS*P_in + vf
        return vf_new
        
        
    def voigt(self,x): 
        v=self.v
        vf=self.vf
        gamL=self.gammaL()
        gamG = self.gammaG(x)
        exp=2*np.sqrt(np.log(2))*(v-vf[x]+complex(0,0.5*gamL))/gamG
        voigt=2*np.sqrt(np.log(2)/pi)*(sp.wofz(exp).real)/gamG
        return voigt

    def Aff(self,x):
        J=self.J
        J_=self.J_
        I=self.I
        F=int(x/10)
        F_=int(x%10)
        print(J,J_,F,F_,I)
        Aff = np.square(wigner_6j(J,J_,1,F,F_,I))*(2*F+1)*(2*F_+1)/(2*I+1)
        print(Aff)
        return(Aff)    

    def abs(self):
        exp=0
        f=self.f
        for i in self.lines:
            exp+=self.Aff(i)*self.voigt(i)
        exp=pi*re*c*f*exp
        return exp #in m^2, not cm^2


    def vapor_pressure_cs(self, T):
        Pv = 0
        if T <301.6:
            logPv=  1088.676/T - 0.08336185*T + 94.88752*math.log10(T) - 219.482
            Pv = 10**logPv
        elif T >301.6:
            logPv=  -4006.048/T - 0.00060194*T - 0.19623*math.log10(T) + 8.22127
            #print(logPv)
            Pv = 10**logPv
            #print(Pv)
        return Pv
    
    def transmittance(self, ax, colour,la,bool_freq):
        if bool_freq:
            v=self.v
        else:
            v=self.v-self.v0
        L=self.Lcell*10**-3
        t=self.T_vap
        trans = []
        Pv = self.vapor_pressure_cs(t) * 133.32236842105263
        print(Pv)
        n = (Pv) / (t * kb)
        a = (-1 * n * L * self.abs())
        print(n)
        for i in a:
            trans.append(math.exp(i))
        ax.plot(v, trans, color=colour)  
        ax.legend(la, bbox_to_anchor=(1.05, 1.0),loc='upper left')


    def transmittance2(self,ax,canvas):
        v=self.v-self.v0
        T=[60,80,100,120]
        t = [temp + 273 for temp in T]
        #print(t)
        L=1.5*10**-3
        trans = [[] for _ in range(len(t))]
        for i in range(len(t)):
            Pv = self.vapor_pressure_cs(t[i]) * 133.32236842105263
            print(Pv)
            n = (Pv) / (t[i] * kb)
            a = (-1 * n * L * self.abs())
            print(n)
            for j in a:
                trans[i].append(math.exp(j)) 
       
        
       
        colors = ['r', 'g', 'b', 'y']  # Different color for each temperature
        for i in range(len(t)):
            ax.plot(v, trans[i], color=colors[i])  # Plot the transmittance values for each temperature
        canvas.draw()
    
    

    
    
    def fwhm(self, v, y, ax):
            scale=2*self.Range/self.samples
            peaks, _ = find_peaks(y)
            print(peaks)
            results_half = peak_widths(y, peaks, rel_height=0.5)
            widths = [str('FWHM: '+'{:,}'.format( round( (i*scale)/10**6, 2 ) ))+"MHz" for i in results_half[0]]
            heights = results_half[1]
            left_ips=[]
            right_ips=[]

            for i in results_half[2]:
                if i<self.samples/2:
                    left_ips.append(-1*scale*(self.samples/2-i))
                else:
                    left_ips.append(scale*(i-self.samples/2))

            for i in results_half[3]:
                if i<self.samples/2:
                    right_ips.append(-1*scale*(self.samples/2-i))
                else:
                    right_ips.append(scale*(i-self.samples/2))
            
                
            #peaks=ax.plot(v[peaks], y[peaks], "x")

            fwhm_lines=ax.hlines(heights, left_ips, right_ips, color="C6", label='_nolegend_')
            print(widths)
            cursor=mplcursors.cursor(fwhm_lines)
            cursor.connect(
            "add", lambda sel: sel.annotation.set_text(widths[sel.index[0]]))
            
            #print(f"Widths: {widths}\n")
            #print(f"Heights: {heights}\n")
            #print(f"Left intersection points: {left_ips}\n")
            #print(f"Right intersection points: {right_ips}\n")
            #return widths
            
    def plot_decomposition(self,ax,col, la, bool_fwhm, bool_area, bool_freq, bool_peaks, col_count):
        if bool_freq:
            v=self.v
        else:
            v=self.v-self.v0
        f=self.f
        y=[];line=[]
        counter=0
        for i,j in enumerate(self.lines):
            y.append(pi*re*c*f*self.Aff(j)*self.voigt(j))
            y[i] = np.array(y[i], dtype=float)
            y[i] = y[i][np.isfinite(y[i])]
            v = v[:len(y[i])]
            line.append(ax.plot(v,y[i],color=col))
            print(y[i])
            counter=counter+1
            if bool_area:
                area=auc(v,y[i])
                area = round(area*10**8, 2)
                ax.fill_between(v, 0, y[i], color=col, alpha=0.1, label='_nolegend_')
                cursor = mplcursors.cursor(line[i])
                cursor.connect("add", lambda sel, area=area: sel.annotation.set_text(f"Area: {area} x $10^{-8}$  Hz-m²"))

            if bool_peaks:
                peaks_pos, _ = find_peaks(y[i])
                peak_plot=ax.plot(v[peaks_pos], y[i][peaks_pos], "x")
                cursor = mplcursors.cursor(peak_plot)
                cursor.connect("add", lambda sel, peak_val=y[i][peaks_pos][0]: sel.annotation.set_text(f"Peak: {round(peak_val*10**16,2)} x $10^{-16}$  m²"))
        
        ax.set_xlabel("Frequency (Hz)")
        ax.set_ylabel("Absorption cross section (m^2)")
        #ax.set_ylim(0,7*10**-16)
        if bool_fwhm:
            [self.fwhm(v,y[i],ax) for i in range(len(self.lines))]
        #fig.tight_layout()
        #plt.figtext(0.01,0.01,f"FWHM: {fwhm}\nArea under curve: {area}\n", c='b')
        
        ax.legend(la, bbox_to_anchor=(1.05, 1.0),loc='upper left')
        leg = ax.get_legend()
        hl_dict = {handle.get_label(): handle for handle in leg.legend_handles}
        #hl_dict[f"_child{col_count-1}"].set_color(col)

    
    def plot_total(self, ax, colour, la, bool_fwhm, bool_area, bool_freq, bool_peaks):
        if bool_freq:
            v=self.v
        else:
            v=self.v-self.v0
        z= self.abs()
        z = np.array(z, dtype=float)
        z = np.abs(z)
        z = z[np.isfinite(z)]
        v = v[:len(z)]
        line=ax.plot(v,z,color=colour)
        area=auc(v,z)
        area = round(area*10**8, 2)

        if bool_area:
            ax.fill_between(v, 0, z, color=colour, alpha=0.1, label='_nolegend_')
            cursor = mplcursors.cursor(line)
            cursor.connect("add", lambda sel: sel.annotation.set_text(f"Area: {area} x $10^{-8}$ Hz-m²"))
        if bool_fwhm:
            self.fwhm(v,z,ax)
        if bool_peaks:
            peaks_pos, _ = find_peaks(z)
            print(peaks_pos, z[peaks_pos], type(z[peaks_pos]))
            peak_plots=ax.plot(v[peaks_pos], z[peaks_pos], "x")
            cursor = mplcursors.cursor(peak_plots)
            cursor.connect("add", lambda sel, peak_vals=z[peaks_pos] : sel.annotation.set_text(f"Peak: {round(peak_vals[sel.index]*10**16,2)} x $10^{-16}$  m²"))
        #plt.figtext(0.01,0.01,f"FWHM: {fwhm}\nArea under curve: {area}\n", c='b')
        ax.set_xlabel("Frequency (Hz)")
        ax.set_ylabel("Absorption cross section (m^2)")
        #ax.legend(handles=labels_)
        ax.legend(la, bbox_to_anchor=(1.05, 1.0), loc='upper left')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Given data
v0 = {
    "Cs": {
        "D1": 335.116048807 * 10**12,
        "D2": 351.72571850 * 10**12,
    },
    "Rb": {
        "D1": 377.1074635 * 10**12,
        "D2": 384.2304844685 * 10**12,
    }
}

vg = {
    "Cs": {
        "D1": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0],
        "D2": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0]
    },
    "Rb": {
        "D1": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0],
        "D2": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0]
    }
}

ve = {
    "Cs": {
        "D1": [0, 0, 0, -656.820 * 10**6, 510.860 * 10**6, 0, 0],
        "D2": [0, 0, -339.7128 * 10**6, -188.4885 * 10**6, 12.79851 * 10**6, 263.8906 * 10**6, 0]
    },
    "Rb": {
        "D1": [0, -510.410 * 10**6, 306.246 * 10**6, 0, 0, 0, 0],
        "D2": [-302.0738 * 10**6, -229.8518 * 10**6, -72.9113 * 10**6, 193.7408 * 10**6, 0, 0, 0]
    }
}

# Calculating Raman detuning model (simplified example)
def raman_detuning(v0, vg, ve):
    return v0 + np.array(vg) + np.array(ve)

# Raman detuning for Cs and Rb D1/D2 transitions
detuning_Cs_D1 = raman_detuning(v0["Cs"]["D1"], vg["Cs"]["D1"], ve["Cs"]["D1"])
detuning_Cs_D2 = raman_detuning(v0["Cs"]["D2"], vg["Cs"]["D2"], ve["Cs"]["D2"])
detuning_Rb_D1 = raman_detuning(v0["Rb"]["D1"], vg["Rb"]["D1"], ve["Rb"]["D1"])
detuning_Rb_D2 = raman_detuning(v0["Rb"]["D2"], vg["Rb"]["D2"], ve["Rb"]["D2"])

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(detuning_Cs_D1, label='Cs D1')
plt.plot(detuning_Cs_D2, label='Cs D2')
plt.plot(detuning_Rb_D1, label='Rb D1')
plt.plot(detuning_Rb_D2, label='Rb D2')

plt.xlabel('Index')
plt.ylabel('Frequency (Hz)')
plt.title('Raman Detuning Model for Cs and Rb D1/D2 Transitions')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
v0 = {
    "Cs": {
        "D1": 335.116048807 * 10**12,
        "D2": 351.72571850 * 10**12,
    },
    "Rb": {
        "D1": 377.1074635 * 10**12,
        "D2": 384.2304844685 * 10**12,
    }
}

vg = {
    "Cs": {
        "D1": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0],
        "D2": [0, 0, 0, 5.170855370625 * 10**9, -4.021776399375 * 10**9, 0, 0]
    },
    "Rb": {
        "D1": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0],
        "D2": [0, 4.2716763181519 * 10**9, -2.56300597908911 * 10**9, 0, 0, 0, 0]
    }
}

ve = {
    "Cs": {
        "D1": [0, 0, 0, -656.820 * 10**6, 510.860 * 10**6, 0, 0],
        "D2": [0, 0, -339.7128 * 10**6, -188.4885 * 10**6, 12.79851 * 10**6, 263.8906 * 10**6, 0]
    },
    "Rb": {
        "D1": [0, -510.410 * 10**6, 306.246 * 10**6, 0, 0, 0, 0],
        "D2": [-302.0738 * 10**6, -229.8518 * 10**6, -72.9113 * 10**6, 193.7408 * 10**6, 0, 0, 0]
    }
}

# Calculate absorption cross-section (simplified example)
def absorption_cross_section(v0, vg, ve):
    return v0 + np.array(vg) + np.array(ve)

# Absorption cross-section for Cs and Rb D1/D2 transitions
absorption_Cs_D1 = absorption_cross_section(v0["Cs"]["D1"], vg["Cs"]["D1"], ve["Cs"]["D1"])
absorption_Cs_D2 = absorption_cross_section(v0["Cs"]["D2"], vg["Cs"]["D2"], ve["Cs"]["D2"])
absorption_Rb_D1 = absorption_cross_section(v0["Rb"]["D1"], vg["Rb"]["D1"], ve["Rb"]["D1"])
absorption_Rb_D2 = absorption_cross_section(v0["Rb"]["D2"], vg["Rb"]["D2"], ve["Rb"]["D2"])

# Plotting the results
plt.figure(figsize=(14, 7))
plt.plot(absorption_Cs_D1, label='Cs D1 Absorption')
plt.plot(absorption_Cs_D2, label='Cs D2 Absorption')
plt.plot(absorption_Rb_D1, label='Rb D1 Absorption')
plt.plot(absorption_Rb_D2, label='Rb D2 Absorption')

plt.xlabel('Index')
plt.ylabel('Frequency (Hz)')
plt.title('Absorption Cross-Section for Cs and Rb D1/D2 Transitions')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters for the Gaussian distribution
mean = 0
standard_deviation = 1

# Generate x values
x = np.linspace(mean - 3*standard_deviation, mean + 3*standard_deviation, 1000)

# Calculate the Gaussian distribution
y = (1 / (standard_deviation * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / standard_deviation) ** 2)

# Plot the graph
plt.plot(x, y)
plt.title('Raman detuning')
plt.xlabel('X')
plt.ylabel('Tranmission freq')
plt.grid(True)
plt.show()
